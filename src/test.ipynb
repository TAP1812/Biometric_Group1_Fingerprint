# %%
import cv2
from utils.ridge_segment import ridge_segment
from utils.ridge_orient import ridge_orient
import numpy as np
from matplotlib import pyplot as plt

# %%
DATASET_PATH = 'D:/Fingerprint Biometrics Authentication System/Dataset/FVC2002/fingerprints/DB2_B/'
original_image = cv2.imread(DATASET_PATH + '101_1.tif', cv2.IMREAD_GRAYSCALE)

# Segment the image with a block size of 16 and threshold of 0.1
normim, mask = ridge_segment(original_image, 16, 0.1)

# Display the results
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(normim)
plt.title('Segmented Image')
# Out:
# Text(0.5, 1.0, 'Segmented Image')
